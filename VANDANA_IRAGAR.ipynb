# %% [markdown]
# <a href="https://colab.research.google.com/github/vandanarekha/TCS-iON/blob/main/VANDANA_IRAGAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division
import numpy as np
import os
import glob
from random import *
from PIL import Image
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.image as mpimg
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Lambda, ELU, Activation, BatchNormalization
from keras.layers.convolutional import Convolution2D, Cropping2D, ZeroPadding2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD, Adam, RMSprop
from google.colab import drive

# %%
drive.mount('/content/gdrive')
d = {}
from subprocess import check_output
with open('/content/gdrive/My Drive/TCS iON/formss.txt') as f:
  for line in f:
    key = line.split(' ')[0]
    writer = line.split(' ')[1]
    d[key] = writer
print(len(d.keys()))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 1539

# %%
tmp = []
target_list = []
path_to_files = os.path.join('gdrive/My Drive/TCS iON/data_subset','*')
for filename in sorted(glob.glob(path_to_files)):    
    tmp.append(filename)
    image_name = filename.split('/')[-1]
    file, ext = os.path.splitext(image_name)
    parts = file.split('-')
    print(parts)
    form = parts[0] + '-' + parts[1]
    
    for key in d:
        if key == form:
            target_list.append(str(d[form]))

img_files = np.asarray(tmp)
img_targets = np.asarray(target_list)
print(img_files)
print(img_targets)
# Out:
# ['j06', '051', 's00', '05']
# ['j06', '051', 's01', '01']
# ['j06', '051', 's02', '00']
# ['j06', '051', 's02', '02']
# ['j06', '051', 's02', '03']
# ['j06', '051', 's03', '00']
# ['j06', '056', 's00', '02']
# ['j06', '056', 's01', '00']
# ['j06', '056', 's01', '01']
# ['j06', '056', 's01', '02']
# ['j06', '056', 's02', '00']
# ['j06', '056', 's02', '01']
# ['m06', '019', 's00', '00']
# ['m06', '019', 's00', '01']
# ['m06', '019', 's01', '00']
# ['m06', '019', 's02', '00']
# ['m06', '019', 's03', '00']
# ['m06', '019', 's04', '00']
# ['m06', '019', 's05', '00']
# ['m06', '019', 's06', '00']
# ['m06', '019', 's07', '01']
# ['m06', '019', 's08', '00']
# ['m06', '019', 's08', '01']
# ['m06', '019', 's09', '00']
# ['m06', '019', 's10', '00']
# ['m06', '019', 's10', '01']
# ['m06', '031', 's00', '00']
# ['m06', '031', 's01', '00']
# ['m06', '031', 's03', '00']
# ['m06', '031', 's04', '00']
# ['m06', '031', 's05', '00']
# ['m06', '031', 's06', '00']
# ['m06', '031', 's06', '01']
# ['m06', '031', 's08', '00']
# ['m06', '031', 's09', '01']
# ['m06', '042', 's00', '00']
# ['m06', '042', 's00', '01']
# ['m06', '042', 's01', '00']
# ['m06', '042', 's01', '01']
# ['m06', '042', 's02', '00']
# ['m06', '042', 's02', '01']
# ['m06', '042', 's03', '00']
# ['m06', '042', 's03', '01']
# ['m06', '042', 's04', '00']
# ['m06', '048', 's00', '00']
# ['m06', '048', 's00', '01']
# ['m06', '048', 's01', '00']
# ['m06', '048', 's01', '01']
# ['m06', '048', 's02', '00']
# ['m06', '048', 's02', '01']
# ['m06', '048', 's04', '00']
# ['m06', '048', 's05', '00']
# ['m06', '048', 's05', '01']
# ['m06', '048', 's06', '00']
# ['m06', '048', 's06', '01']
# ['m06', '056', 's00', '00']
# ['m06', '056', 's02', '00']
# ['m06', '056', 's03', '00']
# ['m06', '056', 's04', '00']
# ['m06', '056', 's04', '01']
# ['m06', '056', 's05', '00']
# ['m06', '056', 's06', '00']
# ['m06', '056', 's06', '01']
# ['m06', '056', 's07', '00']
# ['m06', '056', 's07', '01']
# ['m06', '056', 's08', '01']
# ['m06', '056', 's09', '00']
# ['m06', '067', 's01', '01']
# ['m06', '067', 's02', '00']
# ['m06', '067', 's02', '01']
# ['m06', '067', 's03', '00']
# ['m06', '067', 's03', '01']
# ['m06', '067', 's04', '00']
# ['m06', '067', 's04', '01']
# ['m06', '067', 's05', '00']
# ['m06', '067', 's06', '01']
# ['m06', '067', 's07', '00']
# ['m06', '076', 's00', '00']
# ['m06', '076', 's01', '00']
# ['m06', '076', 's01', '01']
# ['m06', '076', 's02', '00']
# ['m06', '076', 's02', '02']
# ['m06', '076', 's03', '00']
# ['m06', '076', 's04', '00']
# ['m06', '076', 's05', '00']
# ['m06', '076', 's05', '01']
# ['m06', '076', 's05', '02']
# ['m06', '083', 's00', '00']
# ['m06', '083', 's01', '00']
# ['m06', '083', 's01', '01']
# ['m06', '083', 's02', '00']
# ['m06', '083', 's03', '00']
# ['m06', '083', 's03', '02']
# ['m06', '083', 's04', '01']
# ['m06', '083', 's05', '00']
# ['m06', '083', 's05', '01']
# ['m06', '083', 's06', '01']
# ['m06', '091', 's00', '00']
# ['m06', '091', 's01', '00']
# ['m06', '091', 's02', '00']
# ['m06', '091', 's02', '01']
# ['m06', '091', 's03', '00']
# ['m06', '091', 's04', '00']
# ['m06', '091', 's04', '01']
# ['m06', '091', 's05', '00']
# ['m06', '091', 's05', '01']
# ['m06', '098', 's01', '00']
# ['m06', '098', 's02', '00']
# ['m06', '098', 's02', '01']
# ['m06', '098', 's03', '00']
# ['m06', '098', 's04', '00']
# ['m06', '098', 's04', '01']
# ['m06', '098', 's05', '00']
# ['m06', '098', 's06', '00']
# ['m06', '098', 's06', '01']
# ['m06', '098', 's06', '02']
# ['m06', '098', 's06', '03']
# ['m06', '106', 's00', '00']
# ['m06', '106', 's00', '01']
# ['m06', '106', 's00', '02']
# ['m06', '106', 's01', '01']
# ['m06', '106', 's02', '00']
# ['m06', '106', 's02', '01']
# ['m06', '106', 's03', '00']
# ['m06', '106', 's03', '01']
# ['m06', '106', 's03', '02']
# ['m06', '106', 's04', '02']
# ['m06', '106', 's04', '03']
# ['n02', '098', 's00', '00']
# ['n02', '098', 's00', '01']
# ['n02', '098', 's01', '00']
# ['n02', '098', 's01', '02']
# ['n02', '098', 's02', '00']
# ['n02', '098', 's02', '02']
# ['n02', '098', 's03', '00']
# ['n02', '098', 's03', '01']
# ['n02', '098', 's04', '00']
# ['n02', '098', 's04', '01']
# ['n02', '104', 's00', '00']
# ['n02', '104', 's01', '00']
# ['n02', '104', 's01', '01']
# ['n02', '104', 's02', '00']
# ['n02', '104', 's02', '01']
# ['n02', '104', 's02', '02']
# ['n02', '104', 's02', '03']
# ['n02', '104', 's03', '00']
# ['n02', '104', 's03', '01']
# ['n02', '104', 's03', '03']
# ['n02', '109', 's00', '01']
# ['n02', '109', 's00', '02']
# ['n02', '109', 's01', '01']
# ['n02', '109', 's02', '00']
# ['n02', '109', 's02', '01']
# ['n02', '109', 's03', '00']
# ['n02', '109', 's03', '01']
# ['n02', '114', 's00', '00']
# ['n02', '114', 's00', '01']
# ['n02', '114', 's01', '00']
# ['n02', '114', 's02', '00']
# ['n02', '114', 's02', '01']
# ['n02', '114', 's02', '02']
# ['n02', '114', 's04', '00']
# ['n02', '114', 's04', '01']
# ['n02', '114', 's04', '02']
# ['n02', '114', 's04', '03']
# ['n02', '120', 's00', '00']
# ['n02', '120', 's00', '01']
# ['n02', '120', 's00', '02']
# ['n02', '120', 's01', '01']
# ['n02', '120', 's02', '00']
# ['n02', '120', 's03', '00']
# ['n02', '120', 's04', '00']
# ['n02', '120', 's05', '00']
# ['n02', '120', 's05', '01']
# ['n02', '127', 's00', '00']
# ['n02', '127', 's00', '01']
# ['n02', '127', 's01', '00']
# ['n02', '127', 's01', '01']
# ['n02', '127', 's02', '00']
# ['n02', '127', 's02', '01']
# ['n02', '127', 's03', '00']
# ['n02', '127', 's03', '01']
# ['n02', '127', 's04', '00']
# ['n02', '127', 's04', '01']
# ['n02', '127', 's04', '02']
# ['n06', '074', 's00', '00']
# ['n06', '074', 's01', '00']
# ['n06', '074', 's01', '01']
# ['n06', '074', 's01', '02']
# ['n06', '074', 's02', '00']
# ['n06', '074', 's02', '01']
# ['n06', '074', 's04', '00']
# ['n06', '074', 's04', '01']
# ['n06', '074', 's05', '00']
# ['n06', '074', 's06', '01']
# ['n06', '082', 's00', '00']
# ['n06', '082', 's01', '00']
# ['n06', '082', 's04', '01']
# ['n06', '082', 's04', '02']
# ['n06', '082', 's05', '00']
# ['n06', '082', 's06', '01']
# ['n06', '082', 's08', '00']
# ['n06', '082', 's08', '01']
# ['n06', '082', 's08', '02']
# ['n06', '092', 's00', '00']
# ['n06', '092', 's01', '01']
# ['n06', '092', 's02', '00']
# ['n06', '092', 's02', '01']
# ['n06', '092', 's03', '00']
# ['n06', '092', 's04', '00']
# ['n06', '092', 's05', '00']
# ['n06', '092', 's05', '01']
# ['n06', '092', 's06', '00']
# ['n06', '092', 's06', '01']
# ['n06', '092', 's06', '02']
# ['n06', '100', 's00', '00']
# ['n06', '100', 's00', '01']
# ['n06', '100', 's01', '01']
# ['n06', '100', 's03', '01']
# ['n06', '100', 's04', '00']
# ['n06', '100', 's04', '01']
# ['n06', '100', 's04', '02']
# ['n06', '100', 's05', '00']
# ['n06', '100', 's06', '00']
# ['n06', '100', 's08', '00']
# ['n06', '100', 's09', '00']
# ['n06', '100', 's09', '02']
# ['n06', '111', 's00', '00']
# ['n06', '111', 's01', '00']
# ['n06', '111', 's02', '00']
# ['n06', '111', 's02', '01']
# ['n06', '111', 's03', '01']
# ['n06', '111', 's04', '01']
# ['n06', '111', 's04', '02']
# ['n06', '111', 's05', '00']
# ['n06', '111', 's06', '01']
# ['n06', '111', 's06', '02']
# ['n06', '119', 's00', '01']
# ['n06', '119', 's01', '00']
# ['n06', '119', 's01', '02']
# ['n06', '119', 's02', '00']
# ['n06', '119', 's02', '01']
# ['n06', '119', 's02', '02']
# ['n06', '123', 's00', '00']
# ['n06', '123', 's00', '01']
# ['n06', '123', 's01', '00']
# ['n06', '123', 's02', '00']
# ['n06', '123', 's02', '01']
# ['n06', '123', 's02', '02']
# ['n06', '123', 's02', '03']
# ['n06', '123', 's03', '00']
# ['n06', '123', 's03', '01']
# ['n06', '123', 's03', '02']
# ['n06', '123', 's03', '03']
# ['n06', '123', 's03', '04']
# ['n06', '128', 's00', '01']
# ['n06', '128', 's01', '00']
# ['n06', '128', 's01', '02']
# ['n06', '128', 's02', '00']
# ['n06', '128', 's03', '00']
# ['n06', '128', 's03', '01']
# ['n06', '128', 's03', '02']
# ['n06', '133', 's00', '00']
# ['n06', '133', 's01', '00']
# ['n06', '133', 's01', '01']
# ['n06', '133', 's01', '02']
# ['n06', '133', 's02', '00']
# ['n06', '133', 's02', '01']
# ['n06', '133', 's03', '00']
# ['n06', '133', 's03', '01']
# ['n06', '133', 's04', '00']
# ['n06', '133', 's04', '01']
# ['n06', '133', 's05', '00']
# ['n06', '133', 's05', '01']
# ['n06', '133', 's05', '02']
# ['n06', '140', 's00', '00']
# ['n06', '140', 's01', '01']
# ['n06', '140', 's02', '00']
# ['n06', '140', 's02', '01']
# ['n06', '140', 's02', '02']
# ['n06', '140', 's03', '00']
# ['n06', '140', 's04', '00']
# ['n06', '140', 's05', '00']
# ['n06', '140', 's05', '02']
# ['n06', '140', 's06', '00']
# ['n06', '140', 's06', '01']
# ['n06', '148', 's00', '00']
# ['n06', '148', 's00', '01']
# ['n06', '148', 's01', '00']
# ['n06', '148', 's02', '00']
# ['n06', '148', 's02', '01']
# ['n06', '148', 's03', '00']
# ['n06', '148', 's04', '01']
# ['n06', '148', 's05', '00']
# ['n06', '148', 's06', '01']
# ['n06', '156', 's01', '00']
# ['n06', '156', 's01', '01']
# ['n06', '156', 's01', '02']
# ['n06', '156', 's02', '00']
# ['n06', '156', 's04', '00']
# ['n06', '156', 's04', '01']
# ['n06', '156', 's05', '01']
# ['n06', '163', 's00', '00']
# ['n06', '163', 's00', '01']
# ['n06', '163', 's01', '00']
# ['n06', '163', 's01', '02']
# ['n06', '163', 's02', '01']
# ['n06', '163', 's02', '02']
# ['n06', '163', 's04', '00']
# ['n06', '163', 's04', '01']
# ['n06', '163', 's04', '02']
# ['n06', '163', 's04', '03']
# ['n06', '169', 's00', '00']
# ['n06', '169', 's00', '02']
# ['n06', '169', 's00', '03']
# ['n06', '169', 's02', '00']
# ['n06', '169', 's02', '01']
# ['n06', '169', 's03', '00']
# ['n06', '169', 's03', '01']
# ['n06', '169', 's04', '00']
# ['n06', '169', 's04', '01']
# ['n06', '169', 's04', '02']
# ['n06', '175', 's00', '00']
# ['n06', '175', 's01', '00']
# ['n06', '175', 's02', '00']
# ['n06', '175', 's02', '01']
# ['n06', '175', 's02', '02']
# ['n06', '175', 's02', '03']
# ['n06', '175', 's03', '00']
# ['n06', '175', 's03', '01']
# ['n06', '175', 's04', '00']
# ['n06', '175', 's05', '00']
# ['n06', '175', 's05', '01']
# ['n06', '175', 's05', '02']
# ['n06', '182', 's00', '00']
# ['n06', '182', 's00', '01']
# ['n06', '182', 's01', '00']
# ['n06', '182', 's01', '02']
# ['n06', '182', 's01', '03']
# ['n06', '182', 's01', '04']
# ['n06', '182', 's01', '05']
# ['n06', '182', 's02', '00']
# ['n06', '186', 's00', '00']
# ['n06', '186', 's01', '00']
# ['n06', '186', 's01', '01']
# ['n06', '186', 's02', '00']
# ['n06', '186', 's02', '01']
# ['n06', '186', 's03', '00']
# ['n06', '186', 's03', '01']
# ['n06', '186', 's04', '00']
# ['n06', '186', 's04', '01']
# ['n06', '186', 's05', '01']
# ['n06', '186', 's05', '02']
# ['n06', '186', 's06', '00']
# ['n06', '186', 's06', '01']
# ['n06', '194', 's00', '01']
# ['n06', '194', 's01', '00']
# ['n06', '194', 's01', '01']
# ['n06', '194', 's02', '00']
# ['n06', '194', 's02', '01']
# ['n06', '194', 's03', '00']
# ['n06', '194', 's03', '01']
# ['n06', '194', 's04', '00']
# ['n06', '194', 's04', '01']
# ['n06', '194', 's04', '02']
# ['n06', '194', 's04', '03']
# ['n06', '201', 's00', '00']
# ['n06', '201', 's00', '01']
# ['n06', '201', 's00', '02']
# ['n06', '201', 's00', '03']
# ['n06', '201', 's01', '00']
# ['n06', '201', 's01', '01']
# ['n06', '201', 's02', '00']
# ['n06', '201', 's02', '01']
# ['n06', '201', 's02', '02']
# ['n06', '201', 's03', '00']
# ['p03', '057', 's01', '00']
# ['p03', '057', 's02', '00']
# ['p03', '057', 's03', '01']
# ['p03', '057', 's04', '00']
# ['p03', '057', 's05', '00']
# ['p03', '057', 's05', '01']
# ['p03', '057', 's06', '00']
# ['p03', '057', 's07', '00']
# ['p03', '057', 's08', '00']
# ['p03', '057', 's08', '01']
# ['p03', '057', 's10', '00']
# ['p03', '057', 's10', '01']
# ['p03', '087', 's00', '00']
# ['p03', '087', 's01', '00']
# ['p03', '087', 's01', '01']
# ['p03', '087', 's01', '02']
# ['p03', '087', 's01', '03']
# ['p03', '087', 's02', '00']
# ['p03', '087', 's02', '01']
# ['p03', '087', 's03', '00']
# ['p03', '087', 's03', '01']
# ['p03', '087', 's03', '02']
# ['p03', '087', 's04', '01']
# ['p03', '087', 's05', '00']
# ['p03', '087', 's06', '00']
# ['p03', '096', 's00', '00']
# ['p03', '096', 's01', '00']
# ['p03', '096', 's01', '01']
# ['p03', '096', 's02', '00']
# ['p03', '096', 's02', '01']
# ['p03', '096', 's03', '00']
# ['p03', '096', 's03', '01']
# ['p03', '096', 's03', '02']
# ['p03', '096', 's03', '03']
# ['p03', '096', 's04', '01']
# ['p03', '096', 's05', '00']
# ['p03', '096', 's05', '01']
# ['p03', '103', 's00', '00']
# ['p03', '103', 's01', '00']
# ['p03', '103', 's02', '00']
# ['p03', '103', 's03', '00']
# ['p03', '103', 's03', '01']
# ['p03', '103', 's04', '00']
# ['p03', '103', 's05', '00']
# ['p03', '103', 's05', '01']
# ['p03', '103', 's06', '00']
# ['p03', '103', 's06', '01']
# ['p03', '103', 's07', '00']
# ['p03', '112', 's00', '00']
# ['p03', '112', 's00', '01']
# ['p03', '112', 's01', '01']
# ['p03', '112', 's02', '01']
# ['p03', '112', 's04', '00']
# ['p03', '112', 's04', '01']
# ['p03', '112', 's05', '00']
# ['p03', '112', 's05', '01']
# ['p03', '112', 's06', '00']
# ['p03', '112', 's07', '00']
# ['p03', '112', 's07', '02']
# ['p03', '112', 's07', '03']
# ['p06', '030', 's00', '00']
# ['p06', '030', 's01', '00']
# ['p06', '030', 's02', '00']
# ['p06', '030', 's02', '01']
# ['p06', '030', 's03', '00']
# ['p06', '030', 's03', '01']
# ['p06', '030', 's04', '00']
# ['p06', '030', 's06', '00']
# ['p06', '030', 's07', '00']
# ['p06', '030', 's08', '00']
# ['p06', '030', 's08', '01']
# ['p06', '030', 's09', '01']
# ['p06', '030', 's10', '00']
# ['p06', '030', 's10', '01']
# ['p06', '042', 's00', '00']
# ['p06', '042', 's00', '01']
# ['p06', '042', 's00', '02']
# ['p06', '042', 's01', '00']
# ['p06', '042', 's02', '00']
# ['p06', '042', 's02', '01']
# ['p06', '042', 's02', '02']
# ['p06', '042', 's03', '00']
# ['p06', '042', 's03', '01']
# ['p06', '042', 's03', '02']
# ['p06', '042', 's03', '03']
# ['p06', '047', 's00', '00']
# ['p06', '047', 's00', '01']
# ['p06', '047', 's01', '00']
# ['p06', '047', 's01', '01']
# ['p06', '047', 's01', '02']
# ['p06', '047', 's01', '03']
# ['p06', '047', 's02', '01']
# ['p06', '047', 's02', '02']
# ['p06', '047', 's02', '03']
# ['p06', '047', 's02', '04']
# ['p06', '047', 's03', '02']
# ['p06', '052', 's00', '00']
# ['p06', '052', 's00', '01']
# ['p06', '052', 's01', '00']
# ['p06', '052', 's01', '02']
# ['p06', '052', 's01', '03']
# ['p06', '052', 's03', '00']
# ['p06', '052', 's03', '01']
# ['p06', '052', 's03', '02']
# ['p06', '052', 's04', '00']
# ['p06', '058', 's00', '00']
# ['p06', '058', 's01', '00']
# ['p06', '058', 's01', '01']
# ['p06', '058', 's01', '02']
# ['p06', '058', 's02', '00']
# ['p06', '058', 's02', '01']
# ['p06', '058', 's03', '00']
# ['p06', '058', 's04', '00']
# ['p06', '058', 's04', '01']
# ['p06', '058', 's05', '00']
# ['p06', '058', 's05', '01']
# ['p06', '058', 's05', '02']
# ['p06', '058', 's06', '00']
# ['p06', '058', 's08', '00']
# ['p06', '069', 's00', '00']
# ['p06', '069', 's01', '00']
# ['p06', '069', 's01', '03']
# ['p06', '069', 's02', '00']
# ['p06', '069', 's03', '00']
# ['p06', '069', 's04', '00']
# ['p06', '069', 's04', '01']
# ['p06', '069', 's04', '02']
# ['p06', '069', 's04', '03']
# ['p06', '069', 's05', '01']
# ['p06', '069', 's06', '01']
# ['p06', '069', 's06', '02']
# ['p06', '088', 's01', '01']
# ['p06', '088', 's02', '01']
# ['p06', '088', 's03', '00']
# ['p06', '088', 's03', '01']
# ['p06', '088', 's04', '00']
# ['p06', '088', 's04', '01']
# ['p06', '088', 's04', '02']
# ['p06', '088', 's05', '00']
# ['p06', '088', 's05', '01']
# ['p06', '088', 's06', '01']
# ['p06', '096', 's01', '00']
# ['p06', '096', 's01', '01']
# ['p06', '096', 's02', '00']
# ['p06', '096', 's02', '02']
# ['p06', '096', 's03', '00']
# ['p06', '096', 's03', '01']
# ['p06', '096', 's03', '02']
# ['p06', '096', 's04', '01']
# ['p06', '096', 's04', '02']
# ['p06', '096', 's05', '01']
# ['p06', '096', 's06', '00']
# ['p06', '104', 's00', '00']
# ['p06', '104', 's00', '01']
# ['p06', '104', 's00', '02']
# ['p06', '104', 's01', '00']
# ['p06', '104', 's01', '01']
# ['p06', '104', 's02', '00']
# ['p06', '104', 's02', '01']
# ['p06', '104', 's03', '00']
# ['p06', '104', 's03', '01']
# ['p06', '104', 's04', '00']
# ['p06', '104', 's04', '01']
# ['p06', '104', 's05', '00']
# ['p06', '104', 's05', '01']
# ['p06', '104', 's06', '00']
# ['p06', '242', 's00', '00']
# ['p06', '242', 's01', '00']
# ['p06', '242', 's01', '01']
# ['p06', '242', 's01', '02']
# ['p06', '242', 's01', '03']
# ['p06', '242', 's02', '00']
# ['p06', '242', 's02', '01']
# ['p06', '242', 's03', '00']
# ['p06', '242', 's03', '01']
# ['p06', '242', 's04', '00']
# ['p06', '242', 's04', '01']
# ['p06', '242', 's04', '02']
# ['p06', '248', 's00', '00']
# ['p06', '248', 's00', '01']
# ['p06', '248', 's01', '00']
# ['p06', '248', 's01', '01']
# ['p06', '248', 's02', '00']
# ['p06', '248', 's03', '00']
# ['p06', '248', 's03', '01']
# ['p06', '248', 's03', '02']
# ['r03', '053', 's00', '00']
# ['r03', '053', 's00', '01']
# ['r03', '053', 's00', '02']
# ['r03', '053', 's00', '03']
# ['r03', '053', 's00', '04']
# ['r03', '053', 's01', '00']
# ['r03', '053', 's01', '01']
# ['r03', '053', 's01', '02']
# ['r06', '000', 's00', '00']
# ['r06', '000', 's00', '01']
# ['r06', '000', 's00', '02']
# ['r06', '000', 's01', '00']
# ['r06', '000', 's01', '01']
# ['r06', '000', 's01', '02']
# ['r06', '000', 's01', '03']
# ['r06', '003', 's00', '00']
# ['r06', '003', 's00', '01']
# ['r06', '003', 's00', '02']
# ['r06', '003', 's01', '00']
# ['r06', '003', 's01', '01']
# ['r06', '003', 's02', '00']
# ['r06', '003', 's02', '01']
# ['r06', '003', 's02', '02']
# ['r06', '003', 's02', '03']
# ['r06', '003', 's02', '04']
# ['r06', '007', 's00', '00']
# ['r06', '007', 's00', '01']
# ['r06', '007', 's01', '00']
# ['r06', '007', 's01', '01']
# ['r06', '007', 's02', '00']
# ['r06', '007', 's02', '01']
# ['r06', '007', 's02', '02']
# ['r06', '007', 's02', '03']
# ['r06', '007', 's02', '04']
# ['r06', '007', 's02', '05']
# ['r06', '011', 's00', '00']
# ['r06', '011', 's01', '00']
# ['r06', '011', 's01', '01']
# ['r06', '011', 's01', '02']
# ['r06', '011', 's02', '00']
# ['r06', '011', 's02', '01']
# ['r06', '011', 's03', '00']
# ['r06', '011', 's03', '01']
# ['r06', '011', 's04', '00']
# ['r06', '011', 's05', '00']
# ['r06', '018', 's00', '00']
# ['r06', '018', 's00', '01']
# ['r06', '018', 's00', '02']
# ['r06', '018', 's00', '03']
# ['r06', '018', 's01', '00']
# ['r06', '018', 's01', '01']
# ['r06', '018', 's02', '00']
# ['r06', '018', 's02', '01']
# ['r06', '022', 's00', '00']
# ['r06', '022', 's00', '01']
# ['r06', '022', 's00', '02']
# ['r06', '022', 's01', '00']
# ['r06', '022', 's02', '00']
# ['r06', '022', 's02', '01']
# ['r06', '022', 's02', '02']
# ['r06', '022', 's02', '03']
# ['r06', '022', 's03', '00']
# ['r06', '022', 's03', '01']
# ['r06', '022', 's03', '02']
# ['r06', '027', 's00', '00']
# ['r06', '027', 's01', '00']
# ['r06', '027', 's01', '01']
# ['r06', '027', 's02', '00']
# ['r06', '027', 's03', '00']
# ['r06', '027', 's04', '00']
# ['r06', '027', 's04', '01']
# ['r06', '027', 's05', '00']
# ['r06', '027', 's05', '01']
# ['r06', '027', 's06', '00']
# ['r06', '027', 's06', '01']
# ['r06', '035', 's00', '00']
# ['r06', '035', 's00', '01']
# ['r06', '035', 's01', '00']
# ['r06', '035', 's02', '00']
# ['r06', '035', 's02', '01']
# ['r06', '035', 's03', '00']
# ['r06', '035', 's03', '01']
# ['r06', '035', 's04', '00']
# ['r06', '035', 's04', '01']
# ['r06', '035', 's04', '02']
# ['r06', '041', 's00', '00']
# ['r06', '041', 's00', '01']
# ['r06', '041', 's00', '02']
# ['r06', '041', 's00', '03']
# ['r06', '041', 's00', '04']
# ['r06', '041', 's00', '05']
# ['r06', '041', 's01', '00']
# ['r06', '041', 's01', '01']
# ['r06', '041', 's01', '02']
# ['r06', '041', 's01', '03']
# ['r06', '044', 's00', '00']
# ['r06', '044', 's01', '00']
# ['r06', '044', 's01', '01']
# ['r06', '044', 's01', '02']
# ['r06', '044', 's01', '03']
# ['r06', '044', 's02', '00']
# ['r06', '044', 's02', '01']
# ['r06', '044', 's02', '02']
# ['r06', '044', 's03', '00']
# ['r06', '044', 's03', '01']
# ['r06', '044', 's03', '02']
# ['r06', '044', 's03', '03']
# ['r06', '049', 's00', '00']
# ['r06', '049', 's00', '01']
# ['r06', '049', 's00', '02']
# ['r06', '049', 's01', '00']
# ['r06', '049', 's01', '01']
# ['r06', '049', 's01', '02']
# ['r06', '049', 's01', '03']
# ['r06', '049', 's01', '04']
# ['r06', '049', 's02', '00']
# ['r06', '049', 's02', '01']
# ['r06', '049', 's02', '02']
# ['r06', '049', 's02', '03']
# ['r06', '049', 's02', '04']
# ['r06', '053', 's00', '00']
# ['r06', '053', 's00', '01']
# ['r06', '053', 's00', '02']
# ['r06', '053', 's00', '03']
# ['r06', '053', 's01', '00']
# ['r06', '053', 's01', '01']
# ['r06', '053', 's01', '02']
# ['r06', '053', 's02', '00']
# ['r06', '053', 's02', '01']
# ['r06', '053', 's02', '02']
# ['r06', '053', 's02', '03']
# ['r06', '053', 's02', '04']
# ['r06', '057', 's00', '00']
# ['r06', '057', 's01', '00']
# ['r06', '057', 's01', '01']
# ['r06', '057', 's02', '00']
# ['r06', '057', 's02', '01']
# ['r06', '057', 's02', '02']
# ['r06', '057', 's02', '03']
# ['r06', '057', 's03', '00']
# ['r06', '057', 's03', '01']
# ['r06', '057', 's03', '02']
# ['r06', '057', 's03', '03']
# ['r06', '062', 's00', '00']
# ['r06', '062', 's00', '01']
# ['r06', '062', 's01', '00']
# ['r06', '062', 's01', '01']
# ['r06', '062', 's01', '02']
# ['r06', '062', 's02', '00']
# ['r06', '062', 's02', '01']
# ['r06', '062', 's02', '02']
# ['r06', '062', 's02', '03']
# ['r06', '062', 's02', '04']
# ['r06', '062', 's02', '05']
# ['r06', '062', 's02', '06']
# ['r06', '066', 's00', '00']
# ['r06', '066', 's00', '01']
# ['r06', '066', 's00', '02']
# ['r06', '066', 's01', '00']
# ['r06', '066', 's01', '01']
# ['r06', '066', 's01', '02']
# ['r06', '066', 's01', '03']
# ['r06', '066', 's01', '04']
# ['r06', '066', 's02', '00']
# ['r06', '066', 's02', '01']
# ['r06', '066', 's02', '02']
# ['r06', '066', 's02', '03']
# ['r06', '070', 's00', '00']
# ['r06', '070', 's00', '01']
# ['r06', '070', 's00', '02']
# ['r06', '070', 's01', '00']
# ['r06', '070', 's01', '01']
# ['r06', '070', 's02', '00']
# ['r06', '070', 's02', '01']
# ['r06', '070', 's02', '02']
# ['r06', '070', 's03', '00']
# ['r06', '070', 's03', '01']
# ['r06', '070', 's04', '00']
# ['r06', '070', 's04', '01']
# ['r06', '070', 's04', '02']
# ['r06', '070', 's04', '03']
# ['r06', '076', 's00', '00']
# ['r06', '076', 's00', '01']
# ['r06', '076', 's00', '02']
# ['r06', '076', 's00', '03']
# ['r06', '076', 's00', '04']
# ['r06', '076', 's00', '05']
# ['r06', '076', 's01', '00']
# ['r06', '076', 's01', '01']
# ['r06', '076', 's01', '02']
# ['r06', '076', 's01', '03']
# ['r06', '090', 's00', '00']
# ['r06', '090', 's01', '00']
# ['r06', '090', 's01', '01']
# ['r06', '090', 's02', '00']
# ['r06', '090', 's02', '01']
# ['r06', '090', 's03', '00']
# ['r06', '090', 's03', '01']
# ['r06', '090', 's03', '02']
# ['r06', '090', 's03', '03']
# ['r06', '090', 's04', '00']
# ['r06', '090', 's04', '01']
# ['r06', '090', 's05', '00']
# ['r06', '090', 's05', '01']
# ['r06', '097', 's00', '00']
# ['r06', '097', 's00', '01']
# ['r06', '097', 's00', '02']
# ['r06', '097', 's01', '00']
# ['r06', '097', 's01', '01']
# ['r06', '097', 's01', '02']
# ['r06', '097', 's02', '00']
# ['r06', '097', 's02', '01']
# ['r06', '097', 's03', '00']
# ['r06', '097', 's03', '01']
# ['r06', '097', 's04', '00']
# ['r06', '097', 's04', '01']
# ['r06', '097', 's04', '02']
# ['r06', '097', 's04', '03']
# ['r06', '103', 's00', '00']
# ['r06', '103', 's00', '01']
# ['r06', '103', 's00', '02']
# ['r06', '103', 's00', '03']
# ['r06', '103', 's00', '04']
# ['r06', '103', 's00', '05']
# ['r06', '103', 's01', '00']
# ['r06', '103', 's01', '01']
# ['r06', '103', 's01', '02']
# ['r06', '106', 's00', '00']
# ['r06', '106', 's00', '01']
# ['r06', '106', 's00', '02']
# ['r06', '106', 's00', '03']
# ['r06', '106', 's00', '04']
# ['r06', '106', 's01', '00']
# ['r06', '106', 's01', '01']
# ['r06', '106', 's02', '00']
# ['r06', '106', 's02', '01']
# ['r06', '106', 's03', '00']
# ['r06', '106', 's03', '01']
# ['r06', '106', 's03', '02']
# ['r06', '106', 's03', '03']
# ['r06', '111', 's00', '00']
# ['r06', '111', 's00', '01']
# ['r06', '111', 's00', '02']
# ['r06', '111', 's01', '00']
# ['r06', '111', 's01', '01']
# ['r06', '111', 's01', '02']
# ['r06', '111', 's01', '03']
# ['r06', '111', 's02', '00']
# ['r06', '111', 's02', '01']
# ['r06', '111', 's02', '02']
# ['r06', '111', 's02', '03']
# ['r06', '115', 's00', '00']
# ['r06', '115', 's00', '01']
# ['r06', '115', 's00', '02']
# ['r06', '115', 's00', '03']
# ['r06', '115', 's01', '00']
# ['r06', '115', 's02', '00']
# ['r06', '115', 's02', '01']
# ['r06', '115', 's03', '00']
# ['r06', '115', 's03', '01']
# ['r06', '115', 's04', '00']
# ['r06', '115', 's04', '01']
# ['r06', '115', 's04', '02']
# ['r06', '115', 's04', '03']
# ['r06', '115', 's04', '04']
# ['r06', '121', 's00', '00']
# ['r06', '121', 's00', '01']
# ['r06', '121', 's00', '02']
# ['r06', '121', 's00', '03']
# ['r06', '121', 's00', '04']
# ['r06', '121', 's00', '05']
# ['r06', '121', 's01', '00']
# ['r06', '121', 's01', '01']
# ['r06', '121', 's01', '02']
# ['r06', '121', 's02', '00']
# ['r06', '121', 's02', '01']
# ['r06', '121', 's03', '00']
# ['r06', '121', 's03', '01']
# ['r06', '121', 's03', '02']
# ['r06', '126', 's00', '00']
# ['r06', '126', 's00', '01']
# ['r06', '126', 's00', '02']
# ['r06', '126', 's01', '00']
# ['r06', '126', 's01', '01']
# ['r06', '126', 's01', '02']
# ['r06', '126', 's02', '00']
# ['r06', '126', 's02', '01']
# ['r06', '126', 's02', '02']
# ['r06', '126', 's02', '03']
# ['r06', '126', 's02', '04']
# ['r06', '126', 's02', '05']
# ['r06', '126', 's02', '06']
# ['r06', '130', 's00', '00']
# ['r06', '130', 's00', '01']
# ['r06', '130', 's00', '02']
# ['r06', '130', 's01', '00']
# ['r06', '130', 's01', '01']
# ['r06', '130', 's02', '00']
# ['r06', '130', 's02', '01']
# ['r06', '130', 's03', '00']
# ['r06', '130', 's03', '01']
# ['r06', '130', 's04', '00']
# ['r06', '130', 's04', '01']
# ['r06', '130', 's05', '00']
# ['r06', '130', 's05', '01']
# ['r06', '137', 's00', '00']
# ['r06', '137', 's00', '01']
# ['r06', '137', 's00', '02']
# ['r06', '137', 's00', '03']
# ['r06', '137', 's00', '04']
# ['r06', '137', 's01', '00']
# ['r06', '137', 's01', '01']
# ['r06', '137', 's02', '00']
# ['r06', '137', 's02', '01']
# ['r06', '137', 's02', '02']
# ['r06', '137', 's03', '00']
# ['r06', '137', 's04', '00']
# ['r06', '137', 's04', '01']
# ['r06', '137', 's04', '02']
# ['r06', '137', 's04', '03']
# ['r06', '143', 's00', '00']
# ['r06', '143', 's00', '01']
# ['r06', '143', 's01', '00']
# ['r06', '143', 's01', '01']
# ['r06', '143', 's02', '00']
# ['r06', '143', 's03', '00']
# ['r06', '143', 's04', '00']
# ['r06', '143', 's04', '01']
# ['gdrive/My Drive/TCS iON/data_subset/j06-051-s00-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-051-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-051-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-051-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-051-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-051-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s07-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s08-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s08-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s09-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s10-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s10-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s08-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-031-s09-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-042-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-048-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s07-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s07-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s08-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-056-s09-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-067-s07-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-076-s05-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-083-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-091-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s06-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-098-s06-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-106-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-098-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-104-s03-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-109-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-114-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-120-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n02-127-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-074-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s08-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s08-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-082-s08-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-092-s06-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s08-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s09-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-100-s09-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-111-s06-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-119-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s03-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-123-s03-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-128-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-133-s05-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s05-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-140-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-148-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-156-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-163-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-169-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-175-s05-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s01-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s01-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s01-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-182-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s05-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-186-s06-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-194-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/n06-201-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s06-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s07-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s08-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s08-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s10-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-057-s10-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s01-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/p03-087-s03-01.png'
# ...
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-062-s02-06.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s01-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s01-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-066-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-070-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s00-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-076-s01-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s03-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-090-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-097-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s00-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-103-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s00-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-106-s03-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s01-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-111-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-115-s04-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s00-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-121-s03-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-05.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-126-s02-06.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s03-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s05-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-130-s05-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s00-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s00-04.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s02-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s04-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s04-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-137-s04-03.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s03-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s04-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/r06-143-s04-01.png']
# ['415' '415' '415' '415' '415' '415' '415' '415' '415' '415' '415' '415'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552' '552'
#  '552' '552' '552' '552' '552' '552' '552' '552' '567' '567' '567' '567'
#  '567' '567' '567' '567' '567' '567' '315' '315' '315' '315' '315' '315'
#  '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315'
#  '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315'
#  '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315' '315'
#  '315' '315' '315' '315' '315' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '588'
#  '588' '588' '588' '588' '588' '588' '588' '588' '588' '588' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551' '551'
#  '551' '551' '551' '551' '567' '567' '567' '567' '567' '567' '567' '567'
#  '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567'
#  '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567'
#  '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567'
#  '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567' '567'
#  '567' '567' '567' '567' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634' '634'
#  '634' '634' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '315' '315'
#  '315' '315' '315' '315' '315' '315' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635' '635'
#  '635' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670' '670'
#  '670' '670' '670' '670' '670' '670' '670' '670' '670' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671' '671'
#  '671' '671' '671' '671' '671' '671' '635' '635' '635' '635' '635' '635'
#  '635' '635']

# %%
# Visualizing the data
for filename in img_files[6:15]:
    img=mpimg.imread(filename)
    plt.figure(figsize=(10,10))
    plt.imshow(img, cmap ='gray')

# %%
# Label Encode writer names for one hot encoding later
encoder = LabelEncoder()
encoder.fit(img_targets)
encoded_Y = encoder.transform(img_targets)

print(img_files[6:15], img_targets[6:15], encoded_Y[6:15])
# Out:
# ['gdrive/My Drive/TCS iON/data_subset/j06-056-s00-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s01-02.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s02-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/j06-056-s02-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s00-00.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s00-01.png'
#  'gdrive/My Drive/TCS iON/data_subset/m06-019-s01-00.png'] ['415' '415' '415' '415' '415' '415' '551' '551' '551'] [1 1 1 1 1 1 2 2 2]

# %%
#split into test train and validation in ratio 4:1:1

from sklearn.model_selection import train_test_split
train_files, rem_files, train_targets, rem_targets = train_test_split(
        img_files, encoded_Y, train_size=0.66, random_state=52, shuffle= True)

validation_files, test_files, validation_targets, test_targets = train_test_split(
        rem_files, rem_targets, train_size=0.5, random_state=22, shuffle=True)

print(train_files.shape, validation_files.shape, test_files.shape)
print(train_targets.shape, validation_targets.shape, test_targets.shape)
# Out:
# (587,) (151,) (152,)
# (587,) (151,) (152,)

# %%
batch_size = 16
num_classes = 50


def generate_data(samples, target_files,  batch_size=batch_size, factor = 0.1 ):
    num_samples = len(samples)
    from sklearn.utils import shuffle
    while 1: # Loop forever so the generator never terminates
 
        for offset in range(0, num_samples, batch_size):
            batch_samples = samples[offset:offset+batch_size]
            batch_targets = target_files[offset:offset+batch_size]

            images = []
            targets = []
            for i in range(len(batch_samples)):
                batch_sample = batch_samples[i]
                batch_target = batch_targets[i]
                im = Image.open(batch_sample)
                cur_width = im.size[0]
                cur_height = im.size[1]

                
                height_fac = 113 / cur_height

                new_width = int(cur_width * height_fac)
                size = new_width, 113

                imresize = im.resize((size), Image.ANTIALIAS)  
                now_width = imresize.size[0]
                now_height = imresize.size[1]
                

                avail_x_points = list(range(0, now_width - 113 ))

            
                pick_num = int(len(avail_x_points)*factor)

              
                random_startx = sample(avail_x_points,  pick_num)

                for start in random_startx:
                    imcrop = imresize.crop((start, 0, start+113, 113))
                    images.append(np.asarray(imcrop))
                    targets.append(batch_target)

            
            X_train = np.array(images)
            y_train = np.array(targets)

           
            X_train = X_train.reshape(X_train.shape[0], 113, 113, 1)
           
            X_train = X_train.astype('float32')
            X_train /= 255

         
            y_train = to_categorical(y_train, num_classes)

            yield shuffle(X_train, y_train)

# %%
# Generate data for training and validation
train_generator = generate_data(train_files, train_targets, batch_size=batch_size, factor = 0.3)
validation_generator = generate_data(validation_files, validation_targets, batch_size=batch_size, factor = 0.3)
test_generator = generate_data(test_files, test_targets, batch_size=batch_size, factor = 0.1)

# %%
def resize_image(image):
    import tensorflow as tf
    return tf.image.resize_images(image,[56,56])


row, col, ch = 113, 113, 1

model = Sequential()
model.add(ZeroPadding2D((1, 1), input_shape=(row, col, ch)))


#model.add(Lambda(resize_image)) 
#model.add(Lambda(lambda x: resize_image))


model.add(Convolution2D(filters= 32, kernel_size =(5,5), strides= (2,2), padding='same', name='conv1')) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool1'))

model.add(Convolution2D(filters= 64, kernel_size =(3,3), strides= (1,1), padding='same', name='conv2'))  
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool2'))

model.add(Convolution2D(filters= 128, kernel_size =(3,3), strides= (1,1), padding='same', name='conv3')) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2), name='pool3'))


model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(512, name='dense1'))  

model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256, name='dense2'))  
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes,name='output'))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 115, 115, 1)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 58, 58, 32)        832
# _________________________________________________________________
# activation (Activation)      (None, 58, 58, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 29, 29, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 29, 29, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 512)               3211776
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 50)                12850
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# =================================================================
# Total params: 3,449,138
# Trainable params: 3,449,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Saving the model and weights into GDrive

from keras.models import model_from_json   
# serialize model to JSON
model_json = model.to_json()
with open("gdrive/My Drive/Models/HTR_Model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("gdrive/My Drive/Models/HTR_model_weights.hdf5")
print("Saved model to GDrive")
# Out:
# Saved model to GDrive

# %%
#Loading json and weights to recover model
import tensorflow as tf
json_file = open("gdrive/My Drive/Models/HTR_Model.json", 'r')
loaded_model_json = json_file.read()
json_file.close()
l_model = tf.keras.models.model_from_json(loaded_model_json)
# load weights into new model
l_model.load_weights("gdrive/My Drive/Models/HTR_model_weights.hdf5")
print("Loaded model from Gdrive")
# Out:
# Loaded model from Gdrive

# %%
model.save("gdrive/My Drive/Models/HTR_model.hdf5")
print("Saved Keras Model")
# Out:
# Saved Keras Model

# %%
#from keras.models import load_model
# load model
from tensorflow import keras
loaded_model = keras.models.load_model("gdrive/My Drive/Models/HTR_model.hdf5", custom_objects=None, compile=True, options=None)
print("Loaded the Keras Model")
# Out:
# Loaded the Keras Model

# %%
print(loaded_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 115, 115, 1)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 58, 58, 32)        832
# _________________________________________________________________
# activation (Activation)      (None, 58, 58, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 29, 29, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 29, 29, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 29, 29, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 14, 14, 128)       73856
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense1 (Dense)               (None, 512)               3211776
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 50)                12850
# _________________________________________________________________
# activation_5 (Activation)    (None, 50)                0
# =================================================================
# Total params: 3,449,138
# Trainable params: 3,449,138
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
images = []
for filename in test_files[:50]:
    im = Image.open(filename)
    cur_width = im.size[0]
    cur_height = im.size[1]

   
    height_fac = 113 / cur_height

    new_width = int(cur_width * height_fac)
    size = new_width, 113

    imresize = im.resize((size), Image.ANTIALIAS)  
    now_width = imresize.size[0]
    now_height = imresize.size[1]


    avail_x_points = list(range(0, now_width - 113 ))

    
    factor = 0.1
    pick_num = int(len(avail_x_points)*factor)
    
    random_startx = sample(avail_x_points,  pick_num)

    for start in random_startx:
        imcrop = imresize.crop((start, 0, start+113, 113))
        images.append(np.asarray(imcrop))
        
    X_test = np.array(images)
    
    X_test = X_test.reshape(X_test.shape[0], 113, 113, 1)
   
    X_test = X_test.astype('float32')
    X_test /= 255
    shuffle(X_test)

print(X_test.shape)
# Out:
# (5582, 113, 113, 1)

# %%
predictions = loaded_model.predict(X_test, verbose =1)

print(predictions.shape)
predicted_writer = []
for pred in predictions:
    predicted_writer.append(np.argmax(pred))
print(len(predicted_writer))
# Out:
# 175/175 [==============================] - 12s 67ms/step
# (5582, 50)
# 5582

# %%
writer_number = 18
total_images =10
counter = 0
for i in range(len(predicted_writer)//10):
    if predicted_writer[i] == writer_number:
        image = X_test[i].squeeze()
        plt.figure(figsize=(2,2))
        plt.imshow(image, cmap ='gray')

# %%
writer_number = 18
total_images =10
counter = 0
print("Vandana Iragar")
for i in range(len(predicted_writer)//10):
    if predicted_writer[i] == writer_number:
        image = X_test[i].squeeze()
        plt.figure(figsize=(2,2))
        plt.imshow(image, cmap ='gray')
        plt.show()
# Out:
# Vandana Iragar

# %%
def plotgraph(epochs, acc, val_acc):
    # Plot training & validation accuracy values
    plt.plot(epochs, acc, 'b')
    plt.plot(epochs, val_acc, 'r')
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
